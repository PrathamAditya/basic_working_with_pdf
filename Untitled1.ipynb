# %%
import csv

data = open("file_file.csv" , encoding='utf-8')

data_csv = csv.reader(data)
data_list  = list(data_csv)

req_list = []

# %%
# data_list

# %%
for each in data_list[1:]:
    val = 0
    try:
        val = int(each[15][0].strip()
    except (ValueError,IOError) as err :
                  pass
          
    else:
        if val > 0  and val < 5:
            print(each[0])
        
   
           
                
        
    
    
#     print(each[15][0].strip())
#     req_list.append(each[0])
# Out:
#   Input In [26]
#     except (ValueError,IOError) as err :
#     ^
# SyntaxError: invalid syntax

# %%
req_list
# Out:
# ['"Lana Rhoades" ',
#  '"Mia Khalifa" ',
#  '"Riley Reid" ',
#  '"Abella Danger" ',
#  '"Maitland Ward" ',
#  '"Mia Malkova" ',
#  '"Adriana Chechik" ',
#  '"Jessica Jaymes" ',
#  '"Brandi Love" ',
#  '"Nicole Aniston" ',
#  '"Leolulu" ',
#  '"Lela Star" ',
#  '"Angela White" ',
#  '"Alexis Texas" ',
#  '"Lena Paul" ',
#  '"Ava Addams" ',
#  '"Lisa Ann" ',
#  '"Kimmy Granger" ',
#  '"Dillion Harper" ',
#  '"Kendra Lust" ',
#  '"Dani Daniels" ',
#  '"Elsa Jean" ',
#  '"Xev Bellringer" ',
#  '"Sara Jay" ',
#  '"Alexis Fawx" ',
#  '"Asa Akira" ',
#  '"Lena The Plug" ',
#  '"Sarah Banks" ',
#  '"Madison Ivy" ',
#  '"Jessa Rhodes" ',
#  '"Kim Kardashian" ',
#  '"Piper Perri" ',
#  '"Cherie DeVille" ',
#  '"Bridgette B" ',
#  '"Danika Mori" ',
#  '"Eva Lovia" ',
#  '"Tori Black" ',
#  '"Emily Willis" ',
#  '"Karma Rx" ',
#  '"Janice Griffith" ',
#  '"Valentina Nappi" ',
#  '"Peta Jensen" ',
#  '"August Ames" ',
#  '"Sasha Grey" ',
#  '"Leah Gotti" ',
#  '"Nicolette Shea" ',
# ...
